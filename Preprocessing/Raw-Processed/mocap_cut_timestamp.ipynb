# %% [markdown]
# ## MOCAP_cut_timestamp

# %%
import pandas as pd
from scipy.interpolate import interp1d
import numpy as np
from scipy.signal import butter, filtfilt
#插值
def interpolate_column(col):
    # 预处理：用0填充空值
    col_filled = col.fillna(0)
    consecutive_count = 0
    x = np.where(col_filled != 0)[0]
    y = col_filled[col_filled != 0]
    if len(x) > 0:
       f = interp1d(x, y, kind='linear', fill_value='extrapolate')
       col_interp = f(np.arange(len(col_filled)))
    else:
       col_interp = col_filled
    
    return col_interp


#平滑
def butter_lowpass(cutoff, fs, order=5):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return b, a

def apply_lowpass_filter(data, cutoff_freq, fs=1, order=5):
    b, a = butter_lowpass(cutoff_freq, fs, order=order)
    smoothed_data = filtfilt(b, a, data)
    return smoothed_data

# %%
import pandas as pd
import os
import time

def mocap_preprocess(folder_path):
    # 获取指定文件夹下的所有文件和文件夹
    contents = os.listdir(folder_path)
    timestamp_path='C:\\Users\\lyy\\Desktop\\Data\\Raw\\Timestamp'
    for item in contents[:]:
        item_path = os.path.join(folder_path, item)
        
        #浏览对应item的timestamp文件夹
        item_timestamp= os.path.join(timestamp_path,item)
        print('folder：' + item_timestamp)
        
        # 检查是否为文件夹
        if os.path.isdir(item_path):
            print('folder：' + item_path)
        
        #遍历item_kinect下的子文件first、second;遍历item_timestamp下的子文件first、second
        item_contents = os.listdir(item_path)#first和second文件名
        
        for t in item_contents[:]:
            item_path_time = os.path.join(item_path, t) #第item次子文件地址
            item_timestamp_time= os.path.join(item_timestamp, t) #第item次时间戳
            print('folder：'+item_path_time)
            print('folder：'+item_timestamp_time)
            
            #浏览item_timestamp的对应次数时间戳
            timestamp=pd.read_csv(item_timestamp_time+'.csv')
                  
            file_contents = os.listdir(item_path_time)                  
            
            
            for file in file_contents[:4]:
                if file[:-4] == 'task_normal':
                    row = 0
                if file[:-4] == 'task_cup':
                    row = 1
                if file[:-4] == 'task_text':
                    row = 2
                if file[:-4] == 'task_web':
                    row = 3
                
                #导入文件
                file_path = os.path.join(item_path_time, file)
                print('file：'+file_path)
                df_2=pd.read_csv(file_path)#读取文件
                    
                    
                #时间戳转化为数字格式
                for j in range(6):
                    time_array_mocap= time.strptime(timestamp.iloc[row,j+1][:-7], "%Y-%m-%d-%H:%M:%S")
                    timestamp_mocap = time.mktime(time_array_mocap)
                    timestamp_mocap= timestamp_mocap+float(timestamp.iloc[row,j+1][-7:-3])
                    timestamp.iloc[row,j+1]=timestamp_mocap
                        
                #划分时间戳节点
                start=timestamp.iloc[row,1]
                start_kinect=timestamp.iloc[row,2]
                start_turn=timestamp.iloc[row,3]
                end_turn=timestamp.iloc[row,4]
                end_kinect=timestamp.iloc[row,5]
                end=timestamp.iloc[row,6]
                
                #插值和去噪预处理
                ##mocap时间戳➗1000,时间戳在第三列
                for i in range(0,len(df_2)):
                    df_2.iloc[i,2]=df_2.iloc[i,2]/1000
                
                
                #切割开始和结束时间戳
                mocap_new = df_2.copy()
                for i in range(0,len(mocap_new)):
                    timestamp2 = mocap_new.iloc[i,2]
                    if timestamp2 >= start:
                        mocap_new.drop(mocap_new.head(i).index,inplace=True)
                        break
                mocap_new.reset_index(drop=True,inplace=True)
                for i in range(0,len(mocap_new)):
                    timestamp2 = mocap_new.iloc[i,2]
                    if timestamp2 > end :
                        mocap_new.drop(mocap_new.tail(len(mocap_new)-i).index,inplace=True)
                        break
                
                #mocap_new['Timestamp'] = mocap_new['Timestamp'].astype(str)
                
                #插值
                df_3=mocap_new.copy()
                for i in range(3,len(mocap_new.columns)):
                    interpolated_values = interpolate_column(mocap_new.iloc[:,i])
                    df_3.iloc[:,i]=interpolated_values
                # 滤波
                cutoff_frequency = 7.5 # 截止频率
                sampling_frequency = 100  # 采样频率
                filter_order = 4  # 滤波器阶数
                # 对数据框的每一列应用低通滤波器
                df_3.iloc[:,3:].apply(lambda x: apply_lowpass_filter(x, cutoff_frequency, fs=sampling_frequency, order=filter_order))
                
                
                #切分5m去的阶段
                mocap_go = df_3.copy()
                for i in range(0,len(mocap_go)):
                    timestamp2 = mocap_go.iloc[i,2]
                    if timestamp2 >= start:
                        mocap_go.drop(mocap_go.head(i).index,inplace=True)
                        break
                mocap_go.reset_index(drop=True,inplace=True)
                for i in range(0,len(mocap_go)):
                    timestamp2 = mocap_go.iloc[i,2]
                    if timestamp2 > start_turn :
                        mocap_go.drop(mocap_go.tail(len(mocap_go)-i).index,inplace=True)
                        break
                mocap_go['Timestamp'] = mocap_go['Timestamp'].astype(str)
                if len(mocap_go)<2:
                    print("错误")
                    continue
                mocap_go.to_csv("C:\\Users\\lyy\\Desktop\\Data\\Processed\\MOCAP_5m\\"+t+'\\go\\'+file[:-4]+'\\'+item+'_'+file[:-4]+'.csv',index=False)
                #切分2m去的阶段
                #截取go_kinect阶段:start_kinect 到 start_turn
                mocap_go_kinect = df_3.copy()
                for i in range(0,len(mocap_go_kinect)):
                    timestamp2 = mocap_go_kinect.iloc[i,2]
                    if timestamp2 >= start_kinect:
                        mocap_go_kinect.drop(mocap_go_kinect.head(i).index,inplace=True)
                        break
                mocap_go_kinect.reset_index(drop=True,inplace=True)
                for i in range(0,len(mocap_go_kinect)):
                    timestamp2 = mocap_go_kinect.iloc[i,2]
                    if timestamp2 > start_turn :
                        mocap_go_kinect.drop(mocap_go_kinect.tail(len(mocap_go_kinect)-i).index,inplace=True)
                        break
                mocap_go_kinect['Timestamp'] = mocap_go_kinect['Timestamp'].astype(str)              
                mocap_go_kinect.to_csv("C:\\Users\\lyy\\Desktop\\Data\\Processed\\MOCAP_2m\\"+t+'\\go\\'+file[:-4]+'\\'+item+'_'+file[:-4]+'.csv',index=False)          
                
                
                #切分转弯阶段
                #截取turn阶段:start_turn 到 end_turn
                
                mocap_turn = df_3.copy()
                for i in range(0,len(mocap_turn)):
                    timestamp2 = mocap_turn.iloc[i,2]
                    if timestamp2 >= start_turn:
                        mocap_turn.drop(mocap_turn.head(i).index,inplace=True)
                        break
                mocap_turn.reset_index(drop=True,inplace=True)
                for i in range(0,len(mocap_turn)):
                    timestamp2 = mocap_turn.iloc[i,2]
                    if timestamp2 > end_turn :
                        mocap_turn.drop(mocap_turn.tail(len(mocap_turn)-i).index,inplace=True)
                        break
                mocap_turn['Timestamp'] = mocap_turn['Timestamp'].astype(str)
                if len(mocap_turn)<2:
                   print("错误")    
                mocap_turn.to_csv("C:\\Users\\lyy\\Desktop\\Data\\Processed\\MOCAP_5m\\"+t+'\\turn\\'+file[:-4]+'\\'+item+'_'+file[:-4]+'.csv',index=False)  
                mocap_turn.to_csv("C:\\Users\\lyy\\Desktop\\Data\\Processed\\MOCAP_2m\\"+t+'\\turn\\'+file[:-4]+'\\'+item+'_'+file[:-4]+'.csv',index=False)    
                
                #切分5m回去阶段
                #截取back阶段:end_turn 到 end
                mocap_back = df_3.copy()
                for i in range(0,len(mocap_back)):
                    timestamp2 = mocap_back.iloc[i,2]
                    if timestamp2 >= end_turn:
                        mocap_back.drop(mocap_back.head(i).index,inplace=True)
                        break
                mocap_back.reset_index(drop=True,inplace=True)
                for i in range(0,len(mocap_back)):
                    timestamp2 = mocap_back.iloc[i,2]
                    if timestamp2 > end :
                        mocap_back.drop(mocap_back.tail(len(mocap_back)-i).index,inplace=True)
                        break
                mocap_back['Timestamp'] = mocap_back['Timestamp'].astype(str)
       
                mocap_back.to_csv("C:\\Users\\lyy\\Desktop\\Data\\Processed\\MOCAP_5m\\"+t+'\\back\\'+file[:-4]+'\\'+item+'_'+file[:-4]+'.csv',index=False)      
                
                #切分2m回去阶段
                #截取back_kinect阶段:end_turn 到 end_kinect
                mocap_back_kinect = df_3.copy()
                for i in range(0,len(mocap_back_kinect)):
                    timestamp2 = mocap_back_kinect.iloc[i,2]
                    if timestamp2 >= end_turn:
                        mocap_back_kinect.drop(mocap_back_kinect.head(i).index,inplace=True)
                        break
                mocap_back_kinect.reset_index(drop=True,inplace=True)
                for i in range(0,len(mocap_back_kinect)):
                    timestamp2 = mocap_back_kinect.iloc[i,2]
                    if timestamp2 > end_kinect :
                        mocap_back_kinect.drop(mocap_back_kinect.tail(len(mocap_back_kinect)-i).index,inplace=True)
                        break
                mocap_back_kinect['Timestamp'] = mocap_back_kinect['Timestamp'].astype(str)           
                mocap_back_kinect.to_csv("C:\\Users\\lyy\\Desktop\\Data\\Processed\\MOCAP_2m\\"+t+'\\back\\'+file[:-4]+'\\'+item+'_'+file[:-4]+'.csv',index=False)

# %%
mocap_preprocess("C:\\Users\\lyy\\Desktop\\Data\\Raw\\MOCAP")
# Out:
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample01\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample01\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample01\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample01\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample01\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample01\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample01\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample01\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample01\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample01\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample01\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample01\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample02\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample02\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample02\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample02\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample02\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample02\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample02\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample02\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample02\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample02\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample02\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample02\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample03
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample03
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample03\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample03\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample03\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample03\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample03\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample03\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample03\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample03\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample03\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample03\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample03\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample03\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample04
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample04
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample04\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample04\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample04\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample04\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample04\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample04\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample04\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample04\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample04\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample04\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample04\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample04\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample05
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample05
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample05\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample05\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample05\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample05\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample05\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample05\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample05\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample05\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample05\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample05\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample05\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample05\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample06
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample06
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample06\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample06\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample06\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample06\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample06\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample06\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample06\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample06\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample06\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample06\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample06\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample06\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample07
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample07
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample07\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample07\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample07\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample07\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample07\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample07\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample07\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample07\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample07\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample07\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample07\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample07\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample08
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample08
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample08\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample08\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample08\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample08\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample08\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample08\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample08\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample08\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample08\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample08\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample08\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample08\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample09
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample09
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample09\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample09\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample09\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample09\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample09\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample09\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample09\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample09\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample09\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample09\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample09\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample09\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample10
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample10
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample10\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample10\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample10\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample10\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample10\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample10\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample10\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample10\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample10\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample10\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample10\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample10\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample11
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample11
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample11\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample11\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample11\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample11\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample11\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample11\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample11\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample11\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample11\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample11\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample11\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample11\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample12
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample12
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample12\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample12\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample12\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample12\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample12\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample12\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample12\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample12\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample12\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample12\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample12\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample12\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample13
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample13
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample13\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample13\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample13\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample13\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample13\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample13\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample13\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample13\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample13\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample13\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample13\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample13\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample14
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample14
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample14\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample14\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample14\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample14\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample14\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample14\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample14\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample14\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample14\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample14\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample14\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample14\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample15
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample15
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample15\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample15\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample15\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample15\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample15\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample15\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample15\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample15\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample15\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample15\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample15\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample15\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample16
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample16
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample16\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample16\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample16\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample16\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample16\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample16\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample16\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample16\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample16\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample16\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample16\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample16\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample17
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample17
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample17\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample17\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample17\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample17\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample17\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample17\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample17\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample17\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample17\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample17\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample17\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample17\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample18
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample18
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample18\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample18\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample18\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample18\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample18\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample18\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample18\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample18\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample18\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample18\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample18\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample18\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample19
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample19
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample19\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample19\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample19\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample19\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample19\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample19\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample19\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample19\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample19\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample19\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample19\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample19\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample20
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample20
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample20\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample20\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample20\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample20\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample20\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample20\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample20\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample20\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample20\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample20\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample20\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample20\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample21
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample21
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample21\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample21\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample21\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample21\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample21\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample21\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample21\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample21\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample21\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample21\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample21\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample21\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample22
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample22
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample22\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample22\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample22\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample22\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample22\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample22\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample22\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample22\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample22\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample22\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample22\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample22\time02\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample23
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample23
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample23\time01
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample23\time01
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample23\time01\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample23\time01\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample23\time01\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample23\time01\task_web.csv
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample23\time02
# 文件夹：C:\Users\lyy\Desktop\Data\Raw\Timestamp\sample23\time02
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample23\time02\task_cup.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample23\time02\task_normal.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample23\time02\task_text.csv
# 文件：C:\Users\lyy\Desktop\Data\Raw\MOCAP\sample23\time02\task_web.csv
